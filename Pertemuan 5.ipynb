# %% [markdown]
# # Pandas (Panel Data)

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.2'

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
# df = pd.read_csv('patient.csv')

# %%
df_salary = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/Salary_Data.csv')

# %%
df_salary
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
type(df_salary)
# Out:
# pandas.core.frame.DataFrame

# %%
df_salary.shape
# Out:
# (30, 2)

# %%
num_rows, num_cols = df_salary.shape
print ("Number of Rows:", num_rows)
print ("Number of Columns:", num_cols)
# Out:
# Number of Rows: 30
# Number of Columns: 2

# %%
df_salary.head() #secara default, akan menampilkan 5 data pertama
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df_salary.head(10) #menampilkan 10 data pertama
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df_salary.tail() #secara default, akan menampilkan 5 data terakhir
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df_salary.tail(10) #menampilkan 10 data terakhir
# Out:
#     YearsExperience    Salary
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df_patient = pd.read_csv('patient.csv')
df_nba = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
print ("Shape of Dataframe Patient.csv is:", df_patient.shape)
print ("Shape of Dataframe NBA.csv is:", df_nba.shape)
# Out:
# Shape of Dataframe Patient.csv is: (893, 11)
# Shape of Dataframe NBA.csv is: (126314, 23)

# %%
df_patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      893 non-null    int64
#  1   gender          156 non-null    object
#  2   age             156 non-null    float64
#  3   nationality     156 non-null    object
#  4   province        156 non-null    object
#  5   current_state   166 non-null    object
#  6   contacted_with  27 non-null     float64
#  7   confirmed_date  893 non-null    object
#  8   released_date   5 non-null      object
#  9   deceased_date   4 non-null      object
#  10  hospital        17 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 76.9+ KB

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_patient
# Out:
#      patient_id  gender   age nationality     province current_state  \
# 0             1  female  31.0   indonesia  DKI Jakarta      released
# 1             2  female  64.0   indonesia  DKI Jakarta      released
# 2             3  female  33.0   indonesia  DKI Jakarta      released
# 3             4  female  34.0   indonesia  DKI Jakarta      isolated
# 4             5    male  55.0   indonesia  DKI Jakarta      isolated
# ..          ...     ...   ...         ...          ...           ...
# 888         889     NaN   NaN         NaN          NaN           NaN
# 889         890     NaN   NaN         NaN          NaN           NaN
# 890         891     NaN   NaN         NaN          NaN           NaN
# 891         892     NaN   NaN         NaN          NaN           NaN
# 892         893     NaN   NaN         NaN          NaN           NaN
#
#      contacted_with confirmed_date released_date deceased_date  \
# 0               NaN       2-Mar-20     13-Mar-20           NaN
# ...

# %%
df_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df_patient.head(10)
# Out:
#    patient_id  gender   age nationality     province current_state  \
# 0           1  female  31.0   indonesia  DKI Jakarta      released
# 1           2  female  64.0   indonesia  DKI Jakarta      released
# 2           3  female  33.0   indonesia  DKI Jakarta      released
# 3           4  female  34.0   indonesia  DKI Jakarta      isolated
# 4           5    male  55.0   indonesia  DKI Jakarta      isolated
# 5           6    male  36.0   indonesia  DKI Jakarta      released
# 6           7  female  54.0   indonesia  DKI Jakarta      released
# 7           8    male  55.0   indonesia  DKI Jakarta      released
# 8           9  female  55.0   indonesia  DKI Jakarta      released
# 9          10    male  29.0   foreigner  DKI Jakarta      isolated
#
#    contacted_with confirmed_date released_date deceased_date  \
# 0             NaN       2-Mar-20     13-Mar-20           NaN
# 1             1.0       2-Mar-20     16-Mar-20           NaN
# ...

# %%
with pd.option_context("display.max.columns", None):
    df_nba.head(10)
    display (df_nba.head(10))
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts      elo_i      elo_n  win_equiv  \
# 0            0     TRH       Huskies   66  1300.0000  1293.2767  40.294830
# ...

# %%
with pd.option_context("display.max.columns", None, "display.precision", 2):
    df_nba.head(10)
    display (df_nba.head(10))
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# ...

# %%
df_patient.describe()
# Out:
#        patient_id         age  contacted_with
# count  893.000000  156.000000       27.000000
# mean   447.000000   48.108974       30.555556
# std    257.931192   16.627833       36.051601
# min      1.000000    2.000000        1.000000
# 25%    224.000000   36.000000        1.000000
# 50%    447.000000   49.000000        1.000000
# 75%    670.000000   59.000000       74.000000
# max    893.000000   86.000000       83.000000

# %%
df_patient.describe(include="object")
# Out:
#        gender nationality     province current_state confirmed_date  \
# count     156         156          156           166            893
# unique      2           2           10             3             20
# top      male   indonesia  DKI Jakarta      isolated      24-Mar-20
# freq       91         147          124           143            106
#
#        released_date deceased_date              hospital
# count              5             4                    17
# unique             3             2                     4
# top        11-Mar-20     12-Mar-20  RSPI Sulianti Saroso
# freq               2             2                     8

# %%
df_patient.describe(include="all")
# Out:
#         patient_id gender         age nationality     province current_state  \
# count   893.000000    156  156.000000         156          156           166
# unique         NaN      2         NaN           2           10             3
# top            NaN   male         NaN   indonesia  DKI Jakarta      isolated
# freq           NaN     91         NaN         147          124           143
# mean    447.000000    NaN   48.108974         NaN          NaN           NaN
# std     257.931192    NaN   16.627833         NaN          NaN           NaN
# min       1.000000    NaN    2.000000         NaN          NaN           NaN
# 25%     224.000000    NaN   36.000000         NaN          NaN           NaN
# 50%     447.000000    NaN   49.000000         NaN          NaN           NaN
# 75%     670.000000    NaN   59.000000         NaN          NaN           NaN
# max     893.000000    NaN   86.000000         NaN          NaN           NaN
#
# ...

# %%
#Cara akses nama kolom/indeks kolom di dataframe
df_patient["province"]
#type(df_patient["province"])
# Out:
# 0      DKI Jakarta
# 1      DKI Jakarta
# 2      DKI Jakarta
# 3      DKI Jakarta
# 4      DKI Jakarta
#           ...
# 888            NaN
# 889            NaN
# 890            NaN
# 891            NaN
# 892            NaN
# Name: province, Length: 893, dtype: object

# %%
df_patient["province"].value_counts()
# Out:
# DKI Jakarta         124
# Jawa Barat            9
# Jawa Timur            7
# Banten                6
# Jawa Tengah           4
# Kalimantan Barat      2
# Sulawesi Utara        1
# Kepulauan Riau        1
# DI Yogyakarta         1
# Bali                  1
# Name: province, dtype: int64

# %%
df_patient["current_state"].value_counts()
# Out:
# isolated    143
# deceased     15
# released      8
# Name: current_state, dtype: int64

# %%
df_patient["current_state"].nunique()
# Out:
# 3

# %%
df_patient["current_state"].unique()
# Out:
# array(['released', 'isolated', 'deceased', nan], dtype=object)

# %%
df_patient[["gender", "confirmed_date", "hospital"]]
# Out:
#      gender confirmed_date              hospital
# 0    female       2-Mar-20  RSPI Sulianti Saroso
# 1    female       2-Mar-20  RSPI Sulianti Saroso
# 2    female       6-Mar-20  RSPI Sulianti Saroso
# 3    female       6-Mar-20  RSPI Sulianti Saroso
# 4      male       8-Mar-20       RS Persahabatan
# ..      ...            ...                   ...
# 888     NaN      26-Mar-20                   NaN
# 889     NaN      26-Mar-20                   NaN
# 890     NaN      26-Mar-20                   NaN
# 891     NaN      26-Mar-20                   NaN
# 892     NaN      26-Mar-20                   NaN
#
# [893 rows x 3 columns]

# %%
df_patient.loc[:, ["gender", "confirmed_date", "hospital"]]
# Out:
#      gender confirmed_date              hospital
# 0    female       2-Mar-20  RSPI Sulianti Saroso
# 1    female       2-Mar-20  RSPI Sulianti Saroso
# 2    female       6-Mar-20  RSPI Sulianti Saroso
# 3    female       6-Mar-20  RSPI Sulianti Saroso
# 4      male       8-Mar-20       RS Persahabatan
# ..      ...            ...                   ...
# 888     NaN      26-Mar-20                   NaN
# 889     NaN      26-Mar-20                   NaN
# 890     NaN      26-Mar-20                   NaN
# 891     NaN      26-Mar-20                   NaN
# 892     NaN      26-Mar-20                   NaN
#
# [893 rows x 3 columns]

# %%
df_patient.loc[:, "gender"] #command ini menghasilkan tipe data series
# Out:
# 0      female
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 888       NaN
# 889       NaN
# 890       NaN
# 891       NaN
# 892       NaN
# Name: gender, Length: 893, dtype: object

# %%
df_patient.loc[:, ["gender"]]
#df_patient.loc[:, ["gender"]].info() #command ini menghasilkan tipe data dataframe
# Out:
#      gender
# 0    female
# 1    female
# 2    female
# 3    female
# 4      male
# ..      ...
# 888     NaN
# 889     NaN
# 890     NaN
# 891     NaN
# 892     NaN
#
# [893 rows x 1 columns]

# %%
df_patient["gender"].value_counts()
# Out:
# male      91
# female    65
# Name: gender, dtype: int64

# %%
df_patient.loc[df_patient["gender"]=="female", ["gender", "confirmed_date", "hospital"]]
# Out:
#      gender confirmed_date              hospital
# 0    female       2-Mar-20  RSPI Sulianti Saroso
# 1    female       2-Mar-20  RSPI Sulianti Saroso
# 2    female       6-Mar-20  RSPI Sulianti Saroso
# 3    female       6-Mar-20  RSPI Sulianti Saroso
# 6    female       9-Mar-20                   NaN
# ..      ...            ...                   ...
# 157  female      17-Mar-20                   NaN
# 160  female      17-Mar-20                   NaN
# 161  female      17-Mar-20                   NaN
# 164  female      17-Mar-20                   NaN
# 168  female      17-Mar-20                   NaN
#
# [65 rows x 3 columns]

# %%
df_patient.loc[df_patient["gender"]=="male", ["gender", "confirmed_date", "hospital"]]
# Out:
#     gender confirmed_date              hospital
# 4     male       8-Mar-20       RS Persahabatan
# 5     male       8-Mar-20       RS Persahabatan
# 7     male       9-Mar-20                   NaN
# 9     male       9-Mar-20  RSPI Sulianti Saroso
# 11    male       9-Mar-20                   NaN
# ..     ...            ...                   ...
# 165   male      17-Mar-20                   NaN
# 166   male      17-Mar-20                   NaN
# 167   male      17-Mar-20                   NaN
# 169   male      17-Mar-20                   NaN
# 170   male      17-Mar-20                   NaN
#
# [91 rows x 3 columns]

# %%
df_patient["age"].min(), df_patient["age"].max()
# Out:
# (2.0, 86.0)

# %%
df_patient.loc[df_patient["gender"]=="female", "age"].min()
# Out:
# 16.0

# %%
df_patient.loc[df_patient["gender"]=="female", "age"].max()
# Out:
# 80.0

# %%
df_patient.loc[df_patient["gender"]=="male", "age"].min()
# Out:
# 2.0

# %%
df_patient.loc[df_patient["gender"]=="male", "age"].max()
# Out:
# 86.0

# %%
print(df_patient.loc[df_patient["gender"]=="male", "age"].min())
print(df_patient.loc[df_patient["gender"]=="male", "age"].max())
# Out:
# 2.0
# 86.0

# %%
print(df_patient.loc[df_patient["gender"]=="female", "age"].min())
print(df_patient.loc[df_patient["gender"]=="female", "age"].max())
# Out:
# 16.0
# 80.0

# %%
city_revenues = pd.Series(
    [4000, 6500, 13000],
    index=["Amsterdam", "London", "Prague"] #jika index kosong, maka secara default akan menghasilkan index 0, 1, 2, dst
)
print (city_revenues)
print (city_revenues.index)
# Out:
# Amsterdam     4000
# London        6500
# Prague       13000
# dtype: int64
# Index(['Amsterdam', 'London', 'Prague'], dtype='object')

# %%
city_revenues = pd.Series(
    [4000, 6500, 13000],
    #index=["Amsterdam", "London", "Prague"]
)
print (city_revenues)
print (city_revenues.index)
# Out:
# 0     4000
# 1     6500
# 2    13000
# dtype: int64
# RangeIndex(start=0, stop=3, step=1)

# %%
employee_count = pd.Series({
    "Engineers": 10,
    "Business" : 5,
    "Human Resources" : 3
})
print (employee_count)
# Out:
# Engineers          10
# Business            5
# Human Resources     3
# dtype: int64

# %%
employee_count = pd.Series({
    "Amsterdam": 10,
    "London" : 5,
    "Prague" : 3
})
print (employee_count)
# Out:
# Amsterdam    10
# London        5
# Prague        3
# dtype: int64

# %%
city_data = pd.DataFrame({
    "Revenues": city_revenues,
    "employee_count": employee_count
})
city_data
# Out:
#            Revenues  employee_count
# Amsterdam      4000              10
# London         6500               5
# Prague        13000               3

# %%
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Amsterdam to Prague
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Revenues        3 non-null      int64
#  1   employee_count  3 non-null      int64
# dtypes: int64(2)
# memory usage: 152.0+ bytes

# %%
city_data.columns
# Out:
# Index(['Revenues', 'employee_count'], dtype='object')

# %%
print (city_data.columns)
print (df_patient.columns)
print (df_nba.columns)
# Out:
# Index(['Revenues', 'employee_count'], dtype='object')
# Index(['patient_id', 'gender', 'age', 'nationality', 'province',
#        'current_state', 'contacted_with', 'confirmed_date', 'released_date',
#        'deceased_date', 'hospital'],
#       dtype='object')
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df_nba.iloc[:10, [0, 1]]
# Out:
#    gameorder       game_id
# 0          1  194611010TRH
# 1          1  194611010TRH
# 2          2  194611020CHS
# 3          2  194611020CHS
# 4          3  194611020DTF
# 5          3  194611020DTF
# 6          4  194611020PRO
# 7          4  194611020PRO
# 8          5  194611020STB
# 9          5  194611020STB

# %%
df_nba.loc[0]
# Out:
# gameorder                   1
# game_id          194611010TRH
# lg_id                     NBA
# _iscopy                     0
# year_id                  1947
# date_game           11/1/1946
# seasongame                  1
# is_playoffs                 0
# team_id                   TRH
# fran_id               Huskies
# pts                        66
# elo_i                    1300
# elo_n                 1293.28
# win_equiv             40.2948
# opp_id                    NYK
# opp_fran               Knicks
# opp_pts                    68
# opp_elo_i                1300
# opp_elo_n             1306.72
# game_location               H
# game_result                 L
# forecast             0.640065
# notes                     NaN
# Name: 0, dtype: object
